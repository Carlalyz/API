# %% [markdown]
# # 使用三种API开放平台实现人脸识别

# %% [markdown]
# * 使用的单人示例图片
# ![image](https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=3165450438,2790296485&fm=11&gp=0.jpg)
# * 使用的多人示例图片2
# ![image](https://dss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=2907717037,1924937543&fm=111&gp=0.jpg)
# * 使用的多人示例图片2
# ![image](https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=3977127952,2731837736&fm=26&gp=0.jpg)

# %% [markdown]
# ## Azure

# %% [markdown]
# - 单人人脸识别数据

# %%
import requests
import json

# set to your own subscription key value
subscription_key = '03cc7cc2313342d4831cbad7ca6ac426'
assert subscription_key

# replace <My Endpoint String> with the string from your endpoint URL
face_api_url = 'https://eastus.api.cognitive.microsoft.com/face/v1.0/detect'

image_url = 'https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=3165450438,2790296485&fm=11&gp=0.jpg'

headers = {'Ocp-Apim-Subscription-Key': subscription_key}

params = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'false',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise',
}

response = requests.post(face_api_url, params=params,
                         headers=headers, json={"url": image_url})
print(json.dumps(response.json()))
# Out:
# [{"faceId": "7c2896c0-d984-40a1-81f6-13c8841d3f86", "faceRectangle": {"top": 105, "left": 181, "width": 68, "height": 68}, "faceAttributes": {"smile": 0.0, "headPose": {"pitch": 4.2, "roll": 5.2, "yaw": -14.8}, "gender": "male", "age": 23.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.0, "disgust": 0.0, "fear": 0.0, "happiness": 0.0, "neutral": 1.0, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "low", "value": 0.18}, "exposure": {"exposureLevel": "goodExposure", "value": 0.58}, "noise": {"noiseLevel": "low", "value": 0.0}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.13, "invisible": false, "hairColor": [{"color": "black", "confidence": 1.0}, {"color": "gray", "confidence": 0.66}, {"color": "other", "confidence": 0.63}, {"color": "brown", "confidence": 0.33}, {"color": "blond", "confidence": 0.02}, {"color": "red", "confidence": 0.0}]}}}]

# %% [markdown]
# - 多人人脸识别数据1

# %%
import requests
import json

# set to your own subscription key value
subscription_key = '03cc7cc2313342d4831cbad7ca6ac426'
assert subscription_key

# replace <My Endpoint String> with the string from your endpoint URL
face_api_url = 'https://eastus.api.cognitive.microsoft.com/face/v1.0/detect'

image_url = 'https://dss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=2907717037,1924937543&fm=111&gp=0.jpg'

headers = {'Ocp-Apim-Subscription-Key': subscription_key}

params2 = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'false',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise',
}
response2 = requests.post(face_api_url, params=params2,
                         headers=headers, json={"url": image_url})
print(json.dumps(response2.json()))
# Out:
# [{"faceId": "772034e3-0b9c-463f-866b-b076f38009ea", "faceRectangle": {"top": 87, "left": 102, "width": 147, "height": 147}, "faceAttributes": {"smile": 0.0, "headPose": {"pitch": -6.0, "roll": 3.7, "yaw": 31.6}, "gender": "male", "age": 23.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.011, "contempt": 0.003, "disgust": 0.001, "fear": 0.0, "happiness": 0.0, "neutral": 0.922, "sadness": 0.062, "surprise": 0.0}, "blur": {"blurLevel": "low", "value": 0.0}, "exposure": {"exposureLevel": "goodExposure", "value": 0.61}, "noise": {"noiseLevel": "low", "value": 0.1}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.07, "invisible": false, "hairColor": [{"color": "black", "confidence": 0.99}, {"color": "other", "confidence": 0.93}, {"color": "gray", "confidence": 0.46}, {"color": "red", "confidence": 0.1}, {"color": "blond", "confidence": 0.07}, {"color": "brown", "confidence": 0.05}]}}}, {"faceId": "26d2f8cc-95f7-43fc-b9a7-ee2f56a4f2e4", "faceRectangle": {"top": 106, "left": 291, "width": 144, "height": 144}, "faceAttributes": {"smile": 0.011, "headPose": {"pitch": -13.7, "roll": -2.7, "yaw": -1.3}, "gender": "male", "age": 24.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.036, "disgust": 0.0, "fear": 0.0, "happiness": 0.011, "neutral": 0.953, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "low", "value": 0.16}, "exposure": {"exposureLevel": "goodExposure", "value": 0.65}, "noise": {"noiseLevel": "low", "value": 0.0}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.11, "invisible": false, "hairColor": [{"color": "black", "confidence": 0.99}, {"color": "other", "confidence": 0.7}, {"color": "brown", "confidence": 0.48}, {"color": "gray", "confidence": 0.33}, {"color": "red", "confidence": 0.13}, {"color": "blond", "confidence": 0.08}]}}}]

# %% [markdown]
# - 多人人脸识别数据2

# %%
import requests
import json

# set to your own subscription key value
subscription_key = '03cc7cc2313342d4831cbad7ca6ac426'
assert subscription_key

# replace <My Endpoint String> with the string from your endpoint URL
face_api_url = 'https://eastus.api.cognitive.microsoft.com/face/v1.0/detect'

image_url = 'https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=3977127952,2731837736&fm=26&gp=0.jpg'

headers = {'Ocp-Apim-Subscription-Key': subscription_key}

params3 = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'false',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise',
}
response3 = requests.post(face_api_url, params=params3,
                         headers=headers, json={"url": image_url})
print(json.dumps(response3.json()))
# Out:
# [{"faceId": "cd6ae585-9bcf-4d67-8418-bee0b886e104", "faceRectangle": {"top": 83, "left": 349, "width": 80, "height": 80}, "faceAttributes": {"smile": 0.94, "headPose": {"pitch": -2.7, "roll": -1.2, "yaw": 9.7}, "gender": "male", "age": 23.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.0, "disgust": 0.0, "fear": 0.0, "happiness": 0.94, "neutral": 0.0, "sadness": 0.0, "surprise": 0.059}, "blur": {"blurLevel": "low", "value": 0.0}, "exposure": {"exposureLevel": "goodExposure", "value": 0.6}, "noise": {"noiseLevel": "low", "value": 0.0}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.11, "invisible": false, "hairColor": [{"color": "red", "confidence": 0.92}, {"color": "brown", "confidence": 0.72}, {"color": "other", "confidence": 0.71}, {"color": "black", "confidence": 0.66}, {"color": "blond", "confidence": 0.27}, {"color": "gray", "confidence": 0.02}]}}}, {"faceId": "5a28a5dc-a960-4114-a528-f9a57b65d444", "faceRectangle": {"top": 79, "left": 172, "width": 78, "height": 78}, "faceAttributes": {"smile": 1.0, "headPose": {"pitch": 7.6, "roll": 18.0, "yaw": -3.8}, "gender": "male", "age": 22.0, "facialHair": {"moustache": 0.1, "beard": 0.1, "sideburns": 0.1}, "glasses": "NoGlasses", "emotion": {"anger": 0.0, "contempt": 0.0, "disgust": 0.0, "fear": 0.0, "happiness": 1.0, "neutral": 0.0, "sadness": 0.0, "surprise": 0.0}, "blur": {"blurLevel": "low", "value": 0.06}, "exposure": {"exposureLevel": "goodExposure", "value": 0.69}, "noise": {"noiseLevel": "low", "value": 0.01}, "makeup": {"eyeMakeup": true, "lipMakeup": true}, "accessories": [], "occlusion": {"foreheadOccluded": false, "eyeOccluded": false, "mouthOccluded": false}, "hair": {"bald": 0.02, "invisible": false, "hairColor": [{"color": "red", "confidence": 0.96}, {"color": "brown", "confidence": 0.95}, {"color": "other", "confidence": 0.5}, {"color": "black", "confidence": 0.33}, {"color": "blond", "confidence": 0.26}, {"color": "gray", "confidence": 0.01}]}}}]

# %% [markdown]
# ## 腾讯云

# %% [markdown]
# - 单人人脸识别数据

# %%
import hashlib  
import time  
import random  
import string
import requests  
import base64  
import requests

import numpy as np
from urllib.parse import urlencode
import json #用于post后得到的字符串到字典的转换

app_id = '2131690713' 
app_key = 'YDtKcITUF0dF49d3'

'''
        腾讯openai鉴权签名计算步骤：（摘抄自官网）
            用于计算签名的参数在不同接口之间会有差异，但算法过程固定如下4个步骤。
        1 将<key, value>请求参数对按key进行字典升序排序，得到有序的参数对列表N
        2 将列表N中的参数对按URL键值对的格式拼接成字符串，得到字符串T（如：key1=value1&key2=value2），URL键值拼接过程value部分需要URL编码，URL编码算法用大写字母，例如%E8，而不是小写%e8
        3 将应用密钥以app_key为键名，组成URL键值拼接到字符串T末尾，得到字符串S（如：key1=value1&key2=value2&app_key=密钥)
        4 对字符串S进行MD5运算，将得到的MD5值所有字符转换成大写，得到接口请求签名
'''

def face_check(img_data):
    """
    人脸识别demo
    :param img_data: 二进制的图片数据
    :return:
    """

    data = base64.b64encode(img_data)

    image = data.decode()

    imageType = "BASE64"
    
def get_params(img):                         #鉴权计算并返回请求参数
    #请求时间戳（秒级），用于防止请求重放（保证签名5分钟有效
    time_stamp=str(int(time.time())) 
    #请求随机字符串，用于保证签名不可预测,16代表16位
    nonce_str = ''.join(random.sample(string.ascii_letters + string.digits, 16))

    params3 = {'app_id':app_id,                #请求包，需要根据不同的任务修改，基本相同
              'image':img,                    #文字类的任务可能是‘text’，由主函数传递进来
              'mode':'0' ,                    #身份证件类可能是'card_type'
              'time_stamp':time_stamp,        #时间戳，都一样
              'nonce_str':nonce_str,          #随机字符串，都一样
              #'sign':''                      #签名不参与鉴权计算，只是列出来示意
             }

    sort_dict= sorted(params3.items(), key=lambda item:item[0], reverse = False)  #字典排序
    sort_dict.append(('app_key',app_key))   #尾部添加appkey
    rawtext= urlencode(sort_dict).encode()  #urlencod编码
    sha = hashlib.md5()    
    sha.update(rawtext)
    md5text= sha.hexdigest().upper()        #MD5加密计算
    params3['sign']=md5text                  #将签名赋值到sign
    return  params3                          #返回请求包

with open(r"C:\Users\hp\Desktop\666.jpg","rb")as f:
    base64_data = base64.b64encode(f.read())
    
params3 = get_params(base64_data)

url = "https://api.ai.qq.com/fcgi-bin/face/face_detectface"
res = requests.post(url,params3).json()
print(res)
# Out:
# {'ret': 0, 'msg': 'ok', 'data': {'image_width': 440, 'image_height': 330, 'face_list': [{'face_id': '3591758501223865097', 'x': 178, 'y': 96, 'width': 84, 'height': 84, 'gender': 99, 'age': 20, 'expression': 0, 'beauty': 81, 'glass': 0, 'pitch': -6, 'yaw': -3, 'roll': -6, 'face_shape': {'face_profile': [{'x': 190, 'y': 121}, {'x': 188, 'y': 128}, {'x': 187, 'y': 134}, {'x': 187, 'y': 141}, {'x': 188, 'y': 148}, {'x': 189, 'y': 155}, {'x': 191, 'y': 161}, {'x': 194, 'y': 167}, {'x': 199, 'y': 173}, {'x': 204, 'y': 177}, {'x': 210, 'y': 179}, {'x': 218, 'y': 179}, {'x': 225, 'y': 177}, {'x': 232, 'y': 174}, {'x': 238, 'y': 169}, {'x': 242, 'y': 164}, {'x': 246, 'y': 157}, {'x': 248, 'y': 150}, {'x': 250, 'y': 142}, {'x': 251, 'y': 135}, {'x': 251, 'y': 128}], 'left_eye': [{'x': 196, 'y': 122}, {'x': 198, 'y': 124}, {'x': 201, 'y': 124}, {'x': 204, 'y': 124}, {'x': 207, 'y': 123}, {'x': 205, 'y': 120}, {'x': 201, 'y': 119}, {'x': 198, 'y': 120}], 'right_eye': [{'x': 238, 'y': 126}, {'x': 235, 'y': 127}, {'x': 231, 'y': 127}, {'x': 228, 'y': 126}, {'x': 225, 'y': 125}, {'x': 228, 'y': 123}, {'x': 232, 'y': 122}, {'x': 235, 'y': 124}], 'left_eyebrow': [{'x': 192, 'y': 114}, {'x': 196, 'y': 113}, {'x': 201, 'y': 113}, {'x': 205, 'y': 114}, {'x': 210, 'y': 114}, {'x': 206, 'y': 110}, {'x': 201, 'y': 109}, {'x': 196, 'y': 110}], 'right_eyebrow': [{'x': 246, 'y': 120}, {'x': 240, 'y': 118}, {'x': 234, 'y': 117}, {'x': 228, 'y': 117}, {'x': 222, 'y': 116}, {'x': 228, 'y': 113}, {'x': 235, 'y': 112}, {'x': 241, 'y': 114}], 'mouth': [{'x': 202, 'y': 156}, {'x': 205, 'y': 159}, {'x': 208, 'y': 160}, {'x': 212, 'y': 161}, {'x': 215, 'y': 161}, {'x': 219, 'y': 160}, {'x': 222, 'y': 158}, {'x': 219, 'y': 154}, {'x': 216, 'y': 151}, {'x': 212, 'y': 152}, {'x': 209, 'y': 151}, {'x': 205, 'y': 153}, {'x': 206, 'y': 156}, {'x': 209, 'y': 156}, {'x': 212, 'y': 156}, {'x': 215, 'y': 157}, {'x': 219, 'y': 157}, {'x': 219, 'y': 157}, {'x': 216, 'y': 156}, {'x': 212, 'y': 155}, {'x': 209, 'y': 155}, {'x': 206, 'y': 155}], 'nose': [{'x': 214, 'y': 137}, {'x': 216, 'y': 124}, {'x': 213, 'y': 128}, {'x': 211, 'y': 131}, {'x': 208, 'y': 135}, {'x': 205, 'y': 140}, {'x': 209, 'y': 143}, {'x': 213, 'y': 144}, {'x': 217, 'y': 144}, {'x': 223, 'y': 142}, {'x': 221, 'y': 137}, {'x': 219, 'y': 132}, {'x': 217, 'y': 128}]}}]}}

# %% [markdown]
# - 多人人脸识别数据1

# %%
import hashlib  
import time  
import random  
import string
import requests  
import base64  
import requests

import numpy as np
from urllib.parse import urlencode
import json #用于post后得到的字符串到字典的转换

app_id = '2131690713' 
app_key = 'YDtKcITUF0dF49d3'

'''
        腾讯openai鉴权签名计算步骤：（摘抄自官网）
            用于计算签名的参数在不同接口之间会有差异，但算法过程固定如下4个步骤。
        1 将<key, value>请求参数对按key进行字典升序排序，得到有序的参数对列表N
        2 将列表N中的参数对按URL键值对的格式拼接成字符串，得到字符串T（如：key1=value1&key2=value2），URL键值拼接过程value部分需要URL编码，URL编码算法用大写字母，例如%E8，而不是小写%e8
        3 将应用密钥以app_key为键名，组成URL键值拼接到字符串T末尾，得到字符串S（如：key1=value1&key2=value2&app_key=密钥)
        4 对字符串S进行MD5运算，将得到的MD5值所有字符转换成大写，得到接口请求签名
'''

def face_check(img_data):
    """
    人脸识别demo
    :param img_data: 二进制的图片数据
    :return:
    """

    data = base64.b64encode(img_data)

    image = data.decode()

    imageType = "BASE64"
    
def get_params(img):                         #鉴权计算并返回请求参数
    #请求时间戳（秒级），用于防止请求重放（保证签名5分钟有效
    time_stamp=str(int(time.time())) 
    #请求随机字符串，用于保证签名不可预测,16代表16位
    nonce_str = ''.join(random.sample(string.ascii_letters + string.digits, 16))

    params5 = {'app_id':app_id,                #请求包，需要根据不同的任务修改，基本相同
              'image':img,                    #文字类的任务可能是‘text’，由主函数传递进来
              'mode':'0' ,                    #身份证件类可能是'card_type'
              'time_stamp':time_stamp,        #时间戳，都一样
              'nonce_str':nonce_str,          #随机字符串，都一样
              #'sign':''                      #签名不参与鉴权计算，只是列出来示意
             }

    sort_dict= sorted(params5.items(), key=lambda item:item[0], reverse = False)  #字典排序
    sort_dict.append(('app_key',app_key))   #尾部添加appkey
    rawtext= urlencode(sort_dict).encode()  #urlencod编码
    sha = hashlib.md5()    
    sha.update(rawtext)
    md5text= sha.hexdigest().upper()        #MD5加密计算
    params5['sign']=md5text                  #将签名赋值到sign
    return  params5                         #返回请求包

with open(r"C:\Users\hp\Desktop\888.jpg","rb")as f:
    base64_data = base64.b64encode(f.read())
    
params5 = get_params(base64_data)

url = "https://api.ai.qq.com/fcgi-bin/face/face_detectface"
res3 = requests.post(url,params5).json()
print(res3)
# Out:
# {'ret': 0, 'msg': 'ok', 'data': {'image_width': 500, 'image_height': 394, 'face_list': [{'face_id': '3591759581579096117', 'x': 336, 'y': 72, 'width': 99, 'height': 99, 'gender': 99, 'age': 24, 'expression': 69, 'beauty': 83, 'glass': 0, 'pitch': 2, 'yaw': 8, 'roll': 3, 'face_shape': {'face_profile': [{'x': 344, 'y': 107}, {'x': 345, 'y': 117}, {'x': 346, 'y': 127}, {'x': 348, 'y': 136}, {'x': 351, 'y': 145}, {'x': 356, 'y': 154}, {'x': 362, 'y': 161}, {'x': 369, 'y': 168}, {'x': 377, 'y': 173}, {'x': 386, 'y': 176}, {'x': 395, 'y': 176}, {'x': 403, 'y': 172}, {'x': 408, 'y': 166}, {'x': 412, 'y': 159}, {'x': 416, 'y': 151}, {'x': 419, 'y': 143}, {'x': 421, 'y': 135}, {'x': 422, 'y': 127}, {'x': 423, 'y': 119}, {'x': 423, 'y': 111}, {'x': 422, 'y': 103}], 'left_eye': [{'x': 362, 'y': 106}, {'x': 366, 'y': 108}, {'x': 370, 'y': 108}, {'x': 374, 'y': 108}, {'x': 377, 'y': 107}, {'x': 374, 'y': 103}, {'x': 370, 'y': 102}, {'x': 366, 
': 110}, {'x': 230, 'y': 109}, {'x': 227, 'y': 108}, {'x': 224, 'y': 106}, {'x': 227, 'y': 105}, {'x': 232, 'y': 105}, {'x': 235, 'y': 107}], 'left_eyebrow': [{'x': 189, 'y': 85}, {'x': 195, 'y': 85}, {'x': 200, 'y': 87}, {'x': 205, 'y': 89}, {'x': 211, 'y': 91}, {'x': 207, 'y': 86}, {'x': 202, 'y': 83}, {'x': 195, 'y': 82}], 'right_eyebrow': [{'x': 247, 'y': 104}, {'x': 242, 'y': 101}, {'x': 236, 'y': 99}, {'x': 230, 'y': 97}, {'x': 224, 'y': 96}, {'x': 231, 'y': 93}, {'x': 238, 'y': 95}, {'x': 244, 'y': 98}], 'mouth': [{'x': 190, 'y': 132}, {'x': 193, 'y': 138}, {'x': 197, 'y': 142}, {'x': 203, 'y': 144}, {'x': 209, 'y': 145}, {'x': 215, 'y': 144}, {'x': 220, 'y': 140}, {'x': 217, 'y': 135}, {'x': 212, 'y': 130}, {'x': 206, 'y': 130}, {'x': 202, 'y': 128}, {'x' ...

# %% [markdown]
# - 多人人脸识别数据2

# %%
import hashlib  
import time  
import random  
import string
import requests  
import base64  
import requests

import numpy as np
from urllib.parse import urlencode
import json #用于post后得到的字符串到字典的转换

app_id = '2131690713' 
app_key = 'YDtKcITUF0dF49d3'

'''
        腾讯openai鉴权签名计算步骤：（摘抄自官网）
            用于计算签名的参数在不同接口之间会有差异，但算法过程固定如下4个步骤。
        1 将<key, value>请求参数对按key进行字典升序排序，得到有序的参数对列表N
        2 将列表N中的参数对按URL键值对的格式拼接成字符串，得到字符串T（如：key1=value1&key2=value2），URL键值拼接过程value部分需要URL编码，URL编码算法用大写字母，例如%E8，而不是小写%e8
        3 将应用密钥以app_key为键名，组成URL键值拼接到字符串T末尾，得到字符串S（如：key1=value1&key2=value2&app_key=密钥)
        4 对字符串S进行MD5运算，将得到的MD5值所有字符转换成大写，得到接口请求签名
'''

def face_check(img_data):
    """
    人脸识别demo
    :param img_data: 二进制的图片数据
    :return:
    """

    data = base64.b64encode(img_data)

    image = data.decode()

    imageType = "BASE64"
    
def get_params(img):                         #鉴权计算并返回请求参数
    #请求时间戳（秒级），用于防止请求重放（保证签名5分钟有效
    time_stamp=str(int(time.time())) 
    #请求随机字符串，用于保证签名不可预测,16代表16位
    nonce_str = ''.join(random.sample(string.ascii_letters + string.digits, 16))

    params4 = {'app_id':app_id,                #请求包，需要根据不同的任务修改，基本相同
              'image':img,                    #文字类的任务可能是‘text’，由主函数传递进来
              'mode':'0' ,                    #身份证件类可能是'card_type'
              'time_stamp':time_stamp,        #时间戳，都一样
              'nonce_str':nonce_str,          #随机字符串，都一样
              #'sign':''                      #签名不参与鉴权计算，只是列出来示意
             }

    sort_dict= sorted(params4.items(), key=lambda item:item[0], reverse = False)  #字典排序
    sort_dict.append(('app_key',app_key))   #尾部添加appkey
    rawtext= urlencode(sort_dict).encode()  #urlencod编码
    sha = hashlib.md5()    
    sha.update(rawtext)
    md5text= sha.hexdigest().upper()        #MD5加密计算
    params4['sign']=md5text                  #将签名赋值到sign
    return  params4                         #返回请求包

with open(r"C:\Users\hp\Desktop\888.jpg","rb")as f:
    base64_data = base64.b64encode(f.read())
    
params4 = get_params(base64_data)

url = "https://api.ai.qq.com/fcgi-bin/face/face_detectface"
res2 = requests.post(url,params4).json()
print(res2)
# Out:
# {'ret': 0, 'msg': 'ok', 'data': {'image_width': 500, 'image_height': 394, 'face_list': [{'face_id': '3591753050117650479', 'x': 336, 'y': 72, 'width': 99, 'height': 99, 'gender': 99, 'age': 24, 'expression': 69, 'beauty': 83, 'glass': 0, 'pitch': 2, 'yaw': 8, 'roll': 3, 'face_shape': {'face_profile': [{'x': 344, 'y': 107}, {'x': 345, 'y': 117}, {'x': 346, 'y': 127}, {'x': 348, 'y': 136}, {'x': 351, 'y': 145}, {'x': 356, 'y': 154}, {'x': 362, 'y': 161}, {'x': 369, 'y': 168}, {'x': 377, 'y': 173}, {'x': 386, 'y': 176}, {'x': 395, 'y': 176}, {'x': 403, 'y': 172}, {'x': 408, 'y': 166}, {'x': 412, 'y': 159}, {'x': 416, 'y': 151}, {'x': 419, 'y': 143}, {'x': 421, 'y': 135}, {'x': 422, 'y': 127}, {'x': 423, 'y': 119}, {'x': 423, 'y': 111}, {'x': 422, 'y': 103}], 'left_eye': [{'x': 362, 'y': 106}, {'x': 366, 'y': 108}, {'x': 370, 'y': 108}, {'x': 374, 'y': 108}, {'x': 377, 'y': 107}, {'x': 374, 'y': 103}, {'x': 370, 'y': 102}, {'x': 366, 'y': 103}], 'right_eye': [{'x': 412, 'y': 104}, {'x': 409, 'y': 105}, {'x': 406, 'y': 106}, {'x': 402, 'y': 106}, {'x': 399, 'y': 105}, {'x': 401, 'y': 102}, {'x': 405, 'y': 101}, {'x': 409, 'y': 101}], 'left_eyebrow': [{'x': 354, 'y': 97}, {'x': 361, 'y': 96}, {'x': 368, 'y': 96}, {'x': 375, 'y': 96}, {'x': 382, 'y': 96}, {'x': 375, 'y': 92}, {'x': 368, 'y': 91}, {'x': 360, 'y': 92}], 'right_eyebrow': [{'x': 418, 'y': 95}, {'x': 412, 'y': 95}, {'x': 406, 'y': 95}, {'x': 400, 'y': 96}, {'x': 394, 'y': 96}, {'x': 399, 'y': 91}, {'x': 406, 'y': 90}, {'x': 413, 'y': 90}], 'mouth': [{'x': 375, 'y': 144}, {'x': 379, 'y': 150}, {'x': 385, 'y': 155}, {'x': 393, 'y': 155}, {'x': 399, 'y': 153}, {'x': 403, 'y': 148}, {'x': 405, 'y': 141}, {'x': 401, 'y': 138}, {'x': 396, 'y': 136}, {'x': 392, 'y': 137}, {'x': 387, 'y': 137}, {'x': 381, 'y': 139}, {'x': 380, 'y': 147}, {'x': 386, 'y': 150}, {'x': 392, 'y': 151}, {'x': 397, 'y': 149}, {'x': 402, 'y': 145}, {'x': 401, 'y': 140}, {'x': 397, 'y': 139}, {'x': 392, 'y': 140}, {'x': 386, 'y': 140}, {'x': 381, 'y': 142}], 'nose': [{'x': 392, 'y': 123}, {'x': 389, 'y':
headers = {
    'Content-Type': 'application/json',
}

payload = {
    "image_url":img_url,
    'api_key': api_key,
    'api_secret': api_secret,
    'return_attributes':'gender,age,smiling,emotion', 
}

r = requests.post(BASE_URL, params=payload, headers=headers)

r.status_code
print(r.content)
# Out:
# b'{"request_id":"1586678413,8303687f-b39a-4d8c-a1ed-e3eb6cb8e2c7","time_used":1615,"faces":[{"face_token":"73235503620b0906a51a9c601889e823","face_rectangle":{"top":111,"left":184,"width":69,"height":69},"attributes":{"gender":{"value":"Male"},"age":{"value":23},"smile":{"value":0.000,"threshold":50.000},"emotion":{"anger":0.043,"disgust":0.110,"fear":7.423,"happiness":0.196,"neutral":91.465,"sadness":0.482,"surprise":0.281}}}],"image_id":"R+L3q2mPZQ2hLptWYsoaxA==","face_num":1}\n'

# %% [markdown]
# - 多人人脸识别数据1

# %%
import requests


api_secret = "zj8IdhGXyDBhovPklDI7IujNMCIaXbj1"
api_key = '9cibumhegbiNlgMu6EREIYvoDCdjmYpV'  # Replace with a valid Subscription Key here.

BASE_URL = 'https://api-cn.faceplusplus.com/facepp/v3/detect' 
img_url = 'https://dss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=2907717037,1924937543&fm=111&gp=0.jpg'

headers = {
    'Content-Type': 'application/json',
}

payload2 = {
    "image_url":img_url,
    'api_key': api_key,
    'api_secret': api_secret,
    'return_attributes':'gender,age,smiling,emotion', 
}

r2 = requests.post(BASE_URL, params=payload2, headers=headers)

r2.status_code
print(r2.content)
# Out:
# b'{"request_id":"1586693194,bd7a3ee1-a517-4dee-8a35-cb37cd904682","time_used":315,"faces":[{"face_token":"8abcd39e8214bb051432a7c8978b8dea","face_rectangle":{"top":103,"left":83,"width":139,"height":139},"attributes":{"gender":{"value":"Male"},"age":{"value":20},"smile":{"value":3.945,"threshold":50.000},"emotion":{"anger":0.001,"disgust":0.002,"fear":0.001,"happiness":0.003,"neutral":99.993,"sadness":0.001,"surprise":0.000}}},{"face_token":"2fbc42224b078ca69190560c7d79da5a","face_rectangle":{"top":121,"left":297,"width":136,"height":136},"attributes":{"gender":{"value":"Male"},"age":{"value":23},"smile":{"value":0.191,"threshold":50.000},"emotion":{"anger":0.009,"disgust":0.075,"fear":0.009,"happiness":0.071,"neutral":99.708,"sadness":0.059,"surprise":0.069}}}],"image_id":"pF2Grcvj0FZOEj/WxhQv4g==","face_num":2}\n'

# %% [markdown]
# - 多人人脸识别数据2

# %%
import requests


api_secret = "zj8IdhGXyDBhovPklDI7IujNMCIaXbj1"
api_key = '9cibumhegbiNlgMu6EREIYvoDCdjmYpV'  # Replace with a valid Subscription Key here.

BASE_URL = 'https://api-cn.faceplusplus.com/facepp/v3/detect' 
img_url = 'https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=3977127952,2731837736&fm=26&gp=0.jpg'

headers = {
    'Content-Type': 'application/json',
}

payload3 = {
    "image_url":img_url,
    'api_key': api_key,
    'api_secret': api_secret,
    'return_attributes':'gender,age,smiling,emotion', 
}

r3 = requests.post(BASE_URL, params=payload3, headers=headers)

r3.status_code
print(r3.content)
# Out:
# b'{"request_id":"1586693824,d3167853-a737-463a-ae29-5cac084d6157","time_used":242,"faces":[{"face_token":"99e2d92164ff1175e050d3bf54fd5ca8","face_rectangle":{"top":90,"left":342,"width":86,"height":86},"attributes":{"gender":{"value":"Male"},"age":{"value":26},"smile":{"value":99.485,"threshold":50.000},"emotion":{"anger":0.057,"disgust":0.057,"fear":0.111,"happiness":90.433,"neutral":0.187,"sadness":2.979,"surprise":6.175}}},{"face_token":"9381fcb335bd66180355f5f1d66c3211","face_rectangle":{"top":87,"left":170,"width":80,"height":80},"attributes":{"gender":{"value":"Male"},"age":{"value":29},"smile":{"value":100.000,"threshold":50.000},"emotion":{"anger":0.006,"disgust":0.001,"fear":2.460,"happiness":97.526,"neutral":0.006,"sadness":0.001,"surprise":0.001}}}],"image_id":"SmokA8HY4AWApXl4pho2Hw==","face_num":2}\n'

# %% [markdown]
# # 运用Azure分析人脸数据制作数据表格

# %% [markdown]
# - 单人人脸识别

# %%
results = response.json()
results
# Out:
# [{'faceId': '7c2896c0-d984-40a1-81f6-13c8841d3f86',
#   'faceRectangle': {'top': 105, 'left': 181, 'width': 68, 'height': 68},
#   'faceAttributes': {'smile': 0.0,
#    'headPose': {'pitch': 4.2, 'roll': 5.2, 'yaw': -14.8},
#    'gender': 'male',
#    'age': 23.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 1.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.18},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.58},
#    'noise': {'noiseLevel': 'low', 'value': 0.0},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.13,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 1.0},
#      {'color': 'gray', 'confidence': 0.66},
#      {'color': 'other', 'confidence': 0.63},
#      {'color': 'brown', 'confidence': 0.33},
#      {'color': 'blond', 'confidence': 0.02},
#      {'color': 'red', 'confidence': 0.0}]}}}]

# %%
import pandas as pd
df = pd.json_normalize(results)
df = df.rename (columns = {"faceAttributes.smile":"笑容","faceAttributes.headPose.roll":"头部偏向（上下）",
                           "faceAttributes.facialHair.beard":"胡须",
                           "faceAttributes.facialHair.sideburns":"胡须角",
                           "faceAttributes.glasses":"佩戴眼镜",
                           "faceAttributes.emotion.anger":"愤怒",
                           "faceAttributes.emotion.contempt":"鄙视",
                           "faceAttributes.headPose.yaw":"头部偏向（左右）",
                           "faceAttributes.gender":"性别","faceAttributes.age":"年龄",
                           "faceAttributes.facialHair.moustache":"有无胡子",
                           "faceAttributes.noise.value":"噪音值",
                           "faceAttributes.makeup.eyeMakeup":"眼妆",
                           "faceAttributes.makeup.lipMakeup":"唇彩",
                           "faceAttributes.accessories":"配饰",
                           "faceAttributes.occlusion.foreheadOccluded":"前额闭塞",
                           "faceAttributes.occlusion.eyeOccluded":"眼睛开合",
                           "faceAttributes.occlusion.mouthOccluded":"嘴巴开合",
                           "faceAttributes.hair.bald":"秃头程度",
                           "faceAttributes.hair.invisible":"看不见头发",
                           "faceAttributes.hair.hairColor":"发色"})
df = df.set_index('faceId')
df = df.iloc[:,6:]
df.replace({"male":"男",
            "female":"女",
            "NoGlasses":"不佩戴眼镜",
            "Glasses":"佩戴眼镜",})
# Out:
#                                       头部偏向（上下）  头部偏向（左右） 性别    年龄  有无胡子   胡须  \
# faceId
# 7c2896c0-d984-40a1-81f6-13c8841d3f86       5.2     -14.8  男  23.0   0.1  0.1
#
#                                       胡须角   佩戴眼镜   愤怒   鄙视  ...  噪音值    眼妆  \
# faceId                                                      ...
# 7c2896c0-d984-40a1-81f6-13c8841d3f86  0.1  不佩戴眼镜  0.0  0.0  ...  0.0  True
#
#                                         唇彩  配饰   前额闭塞   眼睛开合   嘴巴开合  秃头程度  \
# faceId
# 7c2896c0-d984-40a1-81f6-13c8841d3f86  True  []  False  False  False  0.13
#
#                                       看不见头发  \
# faceId
# 7c2896c0-d984-40a1-81f6-13c8841d3f86  False
#
#                                                                                      发色
# faceId
# 7c2896c0-d984-40a1-81f6-13c8841d3f86  [{'color': 'black', 'confidence': 1.0}, {'colo...
#
# [1 rows x 31 columns]

# %% [markdown]
# - 多人人脸识别 1

# %%
results2 = response2.json()
results2
# Out:
# [{'faceId': '772034e3-0b9c-463f-866b-b076f38009ea',
#   'faceRectangle': {'top': 87, 'left': 102, 'width': 147, 'height': 147},
#   'faceAttributes': {'smile': 0.0,
#    'headPose': {'pitch': -6.0, 'roll': 3.7, 'yaw': 31.6},
#    'gender': 'male',
#    'age': 23.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.011,
#     'contempt': 0.003,
#     'disgust': 0.001,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.922,
#     'sadness': 0.062,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.0},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.61},
#    'noise': {'noiseLevel': 'low', 'value': 0.1},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.07,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 0.99},
#      {'color': 'other', 'confidence': 0.93},
#      {'color': 'gray', 'confidence': 0.46},
#      {'color': 'red', 'confidence': 0.1},
#      {'color': 'blond', 'confidence': 0.07},
#      {'color': 'brown', 'confidence': 0.05}]}}},
#  {'faceId': '26d2f8cc-95f7-43fc-b9a7-ee2f56a4f2e4',
#   'faceRectangle': {'top': 106, 'left': 291, 'width': 144, 'height': 144},
#   'faceAttributes': {'smile': 0.011,
#    'headPose': {'pitch': -13.7, 'roll': -2.7, 'yaw': -1.3},
#    'gender': 'male',
#    'age': 24.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.036,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.011,
#     'neutral': 0.953,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.16},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.65},
#    'noise': {'noiseLevel': 'low', 'value': 0.0},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.11,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 0.99},
#      {'color': 'other', 'confidence': 0.7},
#      {'color': 'brown', 'confidence': 0.48},
#      {'color': 'gray', 'confidence': 0.33},
#      {'color': 'red', 'confidence': 0.13},
#      {'color': 'blond', 'confidence': 0.08}]}}}]

# %%
import pandas as pd
df2 = pd.json_normalize(results2)
df2 = df2.rename (columns = {"faceAttributes.smile":"笑容","faceAttributes.headPose.roll":"头部偏向（上下）",
                           "faceAttributes.facialHair.beard":"胡须",
                           "faceAttributes.facialHair.sideburns":"胡须角",
                           "faceAttributes.glasses":"佩戴眼镜",
                           "faceAttributes.emotion.anger":"愤怒",
                           "faceAttributes.emotion.contempt":"鄙视",
                           "faceAttributes.headPose.yaw":"头部偏向（左右）",
                           "faceAttributes.gender":"性别","faceAttributes.age":"年龄",
                           "faceAttributes.facialHair.moustache":"有无胡子",
                           "faceAttributes.noise.value":"噪音值",
                           "faceAttributes.makeup.eyeMakeup":"眼妆",
                           "faceAttributes.makeup.lipMakeup":"唇彩",
                           "faceAttributes.accessories":"配饰",
                           "faceAttributes.occlusion.foreheadOccluded":"前额闭塞",
                           "faceAttributes.occlusion.eyeOccluded":"眼睛开合",
                           "faceAttributes.occlusion.mouthOccluded":"嘴巴开合",
                           "faceAttributes.hair.bald":"秃头程度",
                           "faceAttributes.hair.invisible":"看不见头发",
                           "faceAttributes.hair.hairColor":"发色"})
df2 = df2.set_index('faceId')
df2 = df2.iloc[:,6:]
df2.replace({"male":"男",
            "female":"女",
            "NoGlasses":"不佩戴眼镜",
            "Glasses":"佩戴眼镜",})
# Out:
#                                       头部偏向（上下）  头部偏向（左右） 性别    年龄  有无胡子   胡须  \
# faceId
# 772034e3-0b9c-463f-866b-b076f38009ea       3.7      31.6  男  23.0   0.1  0.1
# 26d2f8cc-95f7-43fc-b9a7-ee2f56a4f2e4      -2.7      -1.3  男  24.0   0.1  0.1
#
#                                       胡须角   佩戴眼镜     愤怒     鄙视  ...  噪音值  \
# faceId                                                          ...
# 772034e3-0b9c-463f-866b-b076f38009ea  0.1  不佩戴眼镜  0.011  0.003  ...  0.1
# 26d2f8cc-95f7-43fc-b9a7-ee2f56a4f2e4  0.1  不佩戴眼镜  0.000  0.036  ...  0.0
#
#                                         眼妆    唇彩  配饰   前额闭塞   眼睛开合   嘴巴开合  \
# faceId
# 772034e3-0b9c-463f-866b-b076f38009ea  True  True  []  False  False  False
# 26d2f8cc-95f7-43fc-b9a7-ee2f56a4f2e4  True  True  []  False  False  False
#
#                                       秃头程度  看不见头发  \
# faceId
# 772034e3-0b9c-463f-866b-b076f38009ea  0.07  False
# 26d2f8cc-95f7-43fc-b9a7-ee2f56a4f2e4  0.11  False
#
#                                                                                      发色
# faceId
# 772034e3-0b9c-463f-866b-b076f38009ea  [{'color': 'black', 'confidence': 0.99}, {'col...
# 26d2f8cc-95f7-43fc-b9a7-ee2f56a4f2e4  [{'color': 'black', 'confidence': 0.99}, {'col...
#
# [2 rows x 31 columns]

# %% [markdown]
# - 多人人脸识别 2

# %%
results3 = response3.json()
results3
# Out:
# [{'faceId': 'cd6ae585-9bcf-4d67-8418-bee0b886e104',
#   'faceRectangle': {'top': 83, 'left': 349, 'width': 80, 'height': 80},
#   'faceAttributes': {'smile': 0.94,
#    'headPose': {'pitch': -2.7, 'roll': -1.2, 'yaw': 9.7},
#    'gender': 'male',
#    'age': 23.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.94,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.059},
#    'blur': {'blurLevel': 'low', 'value': 0.0},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.6},
#    'noise': {'noiseLevel': 'low', 'value': 0.0},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.11,
#     'invisible': False,
#     'hairColor': [{'color': 'red', 'confidence': 0.92},
#      {'color': 'brown', 'confidence': 0.72},
#      {'color': 'other', 'confidence': 0.71},
#      {'color': 'black', 'confidence': 0.66},
#      {'color': 'blond', 'confidence': 0.27},
#      {'color': 'gray', 'confidence': 0.02}]}}},
#  {'faceId': '5a28a5dc-a960-4114-a528-f9a57b65d444',
#   'faceRectangle': {'top': 79, 'left': 172, 'width': 78, 'height': 78},
#   'faceAttributes': {'smile': 1.0,
#    'headPose': {'pitch': 7.6, 'roll': 18.0, 'yaw': -3.8},
#    'gender': 'male',
#    'age': 22.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.06},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.69},
#    'noise': {'noiseLevel': 'low', 'value': 0.01},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.02,
#     'invisible': False,
#     'hairColor': [{'color': 'red', 'confidence': 0.96},
#      {'color': 'brown', 'confidence': 0.95},
#      {'color': 'other', 'confidence': 0.5},
#      {'color': 'black', 'confidence': 0.33},
#      {'color': 'blond', 'confidence': 0.26},
#      {'color': 'gray', 'confidence': 0.01}]}}}]

# %%
import pandas as pd
df3 = pd.json_normalize(results3)
df3 = df3.rename (columns = {"faceAttributes.smile":"笑容","faceAttributes.headPose.roll":"头部偏向（上下）",
                           "faceAttributes.facialHair.beard":"胡须",
                           "faceAttributes.facialHair.sideburns":"胡须角",
                           "faceAttributes.glasses":"佩戴眼镜",
                           "faceAttributes.emotion.anger":"愤怒",
                           "faceAttributes.emotion.contempt":"鄙视",
                           "faceAttributes.headPose.yaw":"头部偏向（左右）",
                           "faceAttributes.gender":"性别","faceAttributes.age":"年龄",
                           "faceAttributes.facialHair.moustache":"有无胡子",
                           "faceAttributes.noise.value":"噪音值",
                           "faceAttributes.makeup.eyeMakeup":"眼妆",
                           "faceAttributes.makeup.lipMakeup":"唇彩",
                           "faceAttributes.accessories":"配饰",
                           "faceAttributes.occlusion.foreheadOccluded":"前额闭塞",
                           "faceAttributes.occlusion.eyeOccluded":"眼睛开合",
                           "faceAttributes.occlusion.mouthOccluded":"嘴巴开合",
                           "faceAttributes.hair.bald":"秃头程度",
                           "faceAttributes.hair.invisible":"看不见头发",
                           "faceAttributes.hair.hairColor":"发色"})
df3 = df3.set_index('faceId')
df3 = df3.iloc[:,6:]
df3.replace({"male":"男",
            "female":"女",
            "NoGlasses":"不佩戴眼镜",
            "Glasses":"佩戴眼镜",})
# Out:
#                                       头部偏向（上下）  头部偏向（左右） 性别    年龄  有无胡子   胡须  \
# faceId
# cd6ae585-9bcf-4d67-8418-bee0b886e104      -1.2       9.7  男  23.0   0.1  0.1
# 5a28a5dc-a960-4114-a528-f9a57b65d444      18.0      -3.8  男  22.0   0.1  0.1
#
#                                       胡须角   佩戴眼镜   愤怒   鄙视  ...   噪音值    眼妆  \
# faceId                                                      ...
# cd6ae585-9bcf-4d67-8418-bee0b886e104  0.1  不佩戴眼镜  0.0  0.0  ...  0.00  True
# 5a28a5dc-a960-4114-a528-f9a57b65d444  0.1  不佩戴眼镜  0.0  0.0  ...  0.01  True
#
#                                         唇彩  配饰   前额闭塞   眼睛开合   嘴巴开合  秃头程度  \
# faceId
# cd6ae585-9bcf-4d67-8418-bee0b886e104  True  []  False  False  False  0.11
# 5a28a5dc-a960-4114-a528-f9a57b65d444  True  []  False  False  False  0.02
#
#                                       看不见头发  \
# faceId
# cd6ae585-9bcf-4d67-8418-bee0b886e104  False
# 5a28a5dc-a960-4114-a528-f9a57b65d444  False
#
#                                                                                      发色
# faceId
# cd6ae585-9bcf-4d67-8418-bee0b886e104  [{'color': 'red', 'confidence': 0.92}, {'color...
# 5a28a5dc-a960-4114-a528-f9a57b65d444  [{'color': 'red', 'confidence': 0.96}, {'color...
#
# [2 rows x 31 columns]

# %% [markdown]
# # 运用腾讯云分析人脸数据制作数据表格

# %% [markdown]
# - 单人人脸识别

# %%
results5 = res
results5
# Out:
# {'ret': 0,
#  'msg': 'ok',
#  'data': {'image_width': 440,
#   'image_height': 330,
#   'face_list': [{'face_id': '3591505338030914982',
#     'x': 178,
#     'y': 96,
#     'width': 84,
#     'height': 84,
#     'gender': 99,
#     'age': 20,
#     'expression': 0,
#       {'x': 223, 'y': 142},
#       {'x': 221, 'y': 137},
#       {'x': 219, 'y': 132},
#       {'x': 217, 'y': 128}]}}]}}

# %%
import pandas as pd
df5 = pd.json_normalize(results5)
df5 = df5.rename (columns = {"data.face_list":"列表"})
df5.replace({})
# Out:
#    ret msg  data.image_width  data.image_height  \
# 0    0  ok               440                330
#
#                                                   列表
# 0  [{'face_id': '3591505338030914982', 'x': 178, ...

# %% [markdown]
# - 多人人脸识别 1

# %%
results6 = res2
results6
# Out:
# {'ret': 0,
#  'msg': 'ok',
#  'data': {'image_width': 500,
#   'image_height': 334,
#   'face_list': [{'face_id': '3591505377727905191',
#     'x': 59,
#     'y': 66,
#     'width': 181,
#     'height': 181,
#     'gender': 99,
#     'age': 23,
#     'expression': 36,
#     'beauty': 84,
#     'glass': 0,
#     'pitch': 10,
#     'yaw': 24,
#     'roll': 11,
#     'face_shape': {'face_profile': [{'x': 72, 'y': 143},
#       {'x': 76, 'y': 160},
#       {'x': 82, 'y': 176},
#       {'x': 89, 'y': 192},
#       {'x': 98, 'y': 207},
#       {'x': 110, 'y': 218},
#       {'x': 125, 'y': 227},
#       {'x': 141, 'y': 233},
#       {'x': 158, 'y': 237},
#       {'x': 175, 'y': 237},
#       {'x': 191, 'y': 232},
#       {'x': 199, 'y': 222},
#       {'x': 201, 'y': 210},
#       {'x': 203, 'y': 198},
#       {'x': 206, 'y': 186},
#       {'x': 209, 'y': 175},
#       {'x': 212, 'y': 163},
#       {'x': 213, 'y': 151},
#       {'x': 213, 'y': 139},
#       {'x': 211, 'y': 126},
#       {'x': 208, 'y': 116}],
#      'left_eye': [{'x': 125, 'y': 131},
#       {'x': 132, 'y': 133},
#       {'x': 139, 'y': 133},
#       {'x': 146, 'y': 132},
#       {'x': 153, 'y': 130},
#       {'x': 147, 'y': 125},
#       {'x': 139, 'y': 124},
#       {'x': 131, 'y': 126}],
#      'right_eye': [{'x': 202, 'y': 117},
#       {'x': 199, 'y': 121},
#       {'x': 194, 'y': 122},
#       {'x': 189, 'y': 123},
#       {'x': 184, 'y': 123},
#       {'x': 186, 'y': 117},
#       {'x': 191, 'y': 113},
#       {'x': 197, 'y': 113}],
#      'left_eyebrow': [{'x': 109, 'y': 115},
#       {'x': 123, 'y': 114},
#       {'x': 136, 'y': 113},
#       {'x': 150, 'y': 114},
#       {'x': 163, 'y': 113},
#       {'x': 151, 'y': 106},
#       {'x': 136, 'y': 104},
#       {'x': 121, 'y': 106}],
#      'right_eyebrow': [{'x': 204, 'y': 101},
#       {'x': 198, 'y': 104},
#       {'x': 193, 'y': 107},
#       {'x': 187, 'y': 109},
#       {'x': 181, 'y': 111},
#       {'x': 185, 'y': 103},
#       {'x': 191, 'y': 98},
#       {'x': 199, 'y': 95}],
#      'mouth': [{'x': 161, 'y': 204},
#       {'x': 170, 'y': 209},
#       {'x': 180, 'y': 211},
#       {'x': 190, 'y': 210},
#       {'x': 196, 'y': 206},
#       {'x': 199, 'y': 200},
#       {'x': 201, 'y': 192},
#       {'x': 394, 'y': 122},
#       {'x': 408, 'y': 121}],
#      'mouth': [{'x': 342, 'y': 214},
#       {'x': 349, 'y': 221},
#       {'x': 357, 'y': 225},
#       {'x': 366, 'y': 226},
#       {'x': 375, 'y': 223},
#       {'x': 382, 'y': 218},
#       {'x': 387, 'y': 210},
#       {'x': 379, 'y': 209},
#       {'x': 371, 'y': 207},
#       {'x': 364, 'y': 210},
#       {'x': 357, 'y': 209},
#       {'x': 350, 'y': 212},
#       {'x': 350, 'y': 216},
#       {'x': 357, 'y': 216},
#       {'x': 365, 'y': 217},
#       {'x': 372, 'y': 215},
#       {'x': 380, 'y': 213},
#       {'x': 379, 'y': 212},
#       {'x': 372, 'y': 213},
#       {'x': 365, 'y': 215},
#       {'x': 358, 'y': 215},
#       {'x': 350, 'y': 215}],
#      'nose': [{'x': 362, 'y': 186},
#       {'x': 360, 'y': 147},
#       {'x': 356, 'y': 158},
#       {'x': 352, 'y': 168},
#       {'x': 349, 'y': 179},
#       {'x': 345, 'y': 189},
#       {'x': 353, 'y': 193},
#       {'x': 362, 'y': 196},
#       {'x': 371, 'y': 193},
#       {'x': 380, 'y': 187},
#       {'x': 375, 'y': 177},
#       {'x': 370, 'y': 167},
#       {'x': 365, 'y': 157}]}}]}}

# %%
import pandas as pd
df6 = pd.json_normalize(results6)
df6 = df6.rename (columns = {"data.face_list":"列表"})
df6
# Out:
#    ret msg  data.image_width  data.image_height  \
# 0    0  ok               500                334
#
#                                                   列表
# 0  [{'face_id': '3591505377727905191', 'x': 59, '...

# %% [markdown]
# - 多人人脸识别 2

# %%
results7 = res3
results7
# Out:
# {'ret': 0,
#  'msg': 'ok',
#  'data': {'image_width': 500,
#   'image_height': 394,
#   'face_list': [{'face_id': '3591759581579096117',
#     'x': 336,
#     'y': 72,
#     'width': 99,
#     'height': 99,
#     'gender': 99,
#     'age': 24,
#     'expression': 69,
#     'beauty': 83,
#     'glass': 0,
#     'pitch': 2,
#     'yaw': 8,
#     'roll': 3,
#     'face_shape': {'face_profile': [{'x': 344, 'y': 107},
#       {'x': 345, 'y': 117},
#       {'x': 346, 'y': 127},
#       {'x': 348, 'y': 136},
#       {'x': 351, 'y': 145},
#       {'x': 356, 'y': 154},
#       {'x': 362, 'y': 161},
#       {'x': 369, 'y': 168},
#       {'x': 377, 'y': 173},
#       {'x': 386, 'y': 176},
#       {'x': 395, 'y': 176},
#       {'x': 403, 'y': 172},
#       {'x': 408, 'y': 166},
#       {'x': 412, 'y': 159},
#       {'x': 416, 'y': 151},
#       {'x': 419, 'y': 143},
#       {'x': 421, 'y': 135},
#       {'x': 422, 'y': 127},
#       {'x': 423, 'y': 119},
#       {'x': 423, 'y': 111},
#       {'x': 422, 'y': 103}],
#      'left_eye': [{'x': 362, 'y': 106},
#       {'x': 366, 'y': 108},
#       {'x': 370, 'y': 108},
#       {'x': 374, 'y': 108},
#       {'x': 377, 'y': 107},
#       {'x': 374, 'y': 103},
#       {'x': 370, 'y': 102},
#       {'x': 366, 'y': 103}],
#      'left_eye': [{'x': 192, 'y': 96},
#       {'x': 195, 'y': 98},
#       {'x': 198, 'y': 99},
#       {'x': 201, 'y': 100},
#       {'x': 205, 'y': 100},
#       {'x': 203, 'y': 97},
#       {'x': 200, 'y': 94},
#       {'x': 195, 'y': 94}],
#      'right_eye': [{'x': 237, 'y': 110},
#       {'x': 234, 'y': 110},
#       {'x': 230, 'y': 109},
#       {'x': 227, 'y': 108},
#       {'x': 224, 'y': 106},
#       {'x': 227, 'y': 105},
#       {'x': 232, 'y': 105},
#       {'x': 235, 'y': 107}],
#      'left_eyebrow': [{'x': 189, 'y': 85},
#       {'x': 195, 'y': 85},
#       {'x': 200, 'y': 87},
#       {'x': 205, 'y': 89},
#       {'x': 211, 'y': 91},
#       {'x': 207, 'y': 86},
#       {'x': 202, 'y': 83},
#       {'x': 195, 'y': 82}],
#      'right_eyebrow': [{'x': 247, 'y': 104},
#       {'x': 242, 'y': 101},
#       {'x': 236, 'y': 99},
#       {'x': 230, 'y': 97},
#       {'x': 224, 'y': 96},
#       {'x': 231, 'y': 93},
#       {'x': 238, 'y': 95},
#       {'x': 244, 'y': 98}],
#      'mouth': [{'x': 190, 'y': 132},
#       {'x': 193, 'y': 138},
#       {'x': 197, 'y': 142},
#       {'x': 203, 'y': 144},
#       {'x': 209, 'y': 145},
#       {'x': 215, 'y': 144},
#       {'x': 220, 'y': 140},
#       {'x': 217, 'y': 135},
#       {'x': 212, 'y': 130},
#       {'x': 206, 'y': 130},
#       {'x': 202, 'y': 128},
#       {'x': 196, 'y': 129},
#       {'x': 195, 'y': 134},
#       {'x': 199, 'y': 136},
#       {'x': 204, 'y': 138},
#       {'x': 210, 'y': 139},
#       {'x': 215, 'y': 140},
#       {'x': 216, 'y': 137},
#       {'x': 211, 'y': 135},
#       {'x': 206, 'y': 133},
#       {'x': 201, 'y': 132},
#       {'x': 195, 'y': 131}],
#      'nose': [{'x': 209, 'y': 116},
#       {'x': 214, 'y': 103},
#       {'x': 210, 'y': 106},
#       {'x': 207, 'y': 109},
#       {'x': 203, 'y': 113},
#       {'x': 198, 'y': 117},
#       {'x': 202, 'y': 121},
#       {'x': 207, 'y': 123},
#       {'x': 212, 'y': 125},
#       {'x': 218, 'y': 124},
#       {'x': 217, 'y': 117},
#       {'x': 216, 'y': 113},
#       {'x': 215, 'y': 108}]}}]}}

# %%
import pandas as pd
df7 = pd.json_normalize(results7)
df7 = df7.rename (columns = {"data.face_list":"列表"})
df7
# Out:
#    ret msg  data.image_width  data.image_height  \
# 0    0  ok               500                394
#
#                                                   列表
# 0  [{'face_id': '3591759581579096117', 'x': 336, ...

# %% [markdown]
# # 运用Face++分析人脸数据制作数据表格

# %% [markdown]
# - 单人人脸识别

# %%
results3 = r.json()
results3
# Out:
# {'request_id': '1586678413,8303687f-b39a-4d8c-a1ed-e3eb6cb8e2c7',
#  'time_used': 1615,
#  'faces': [{'face_token': '73235503620b0906a51a9c601889e823',
#    'face_rectangle': {'top': 111, 'left': 184, 'width': 69, 'height': 69},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 23},
#     'smile': {'value': 0.0, 'threshold': 50.0},
#     'emotion': {'anger': 0.043,
#      'disgust': 0.11,
#      'fear': 7.423,
#      'happiness': 0.196,
#      'neutral': 91.465,
#      'sadness': 0.482,
#      'surprise': 0.281}}}],
#  'image_id': 'R+L3q2mPZQ2hLptWYsoaxA==',
#  'face_num': 1}

# %%
import pandas as pd
df3 = pd.json_normalize(results3,record_path='faces')
df3 = df3.rename (columns = {"attributes.gender.value":"性别",
                           "attributes.age.value":"年龄",
                           "attributes.smile.value":"笑容",
                           "attributes.smile.threshold":"是否有笑容",
                           "attributes.emotion.anger":"愤怒",
                           "attributes.emotion.disgust":"厌恶",
                           "attributes.emotion.fear":"恐惧",
                           "attributes.emotion.happiness":"高兴",
                           "attributes.emotion.neutral":"平静",
                           "attributes.emotion.sadness":"悲伤",
                           "attributes.emotion.surprise":"惊讶"})
df3 = df3.set_index('face_token')
df3 = df3.iloc[:,4:]
df3.replace({"Male":"男",
            "Female":"女",})
# Out:
#                                  性别  年龄   笑容  是否有笑容     愤怒    厌恶     恐惧  \
# face_token
# 73235503620b0906a51a9c601889e823  男  23  0.0   50.0  0.043  0.11  7.423
#
#                                      高兴      平静     悲伤     惊讶
# face_token
# 73235503620b0906a51a9c601889e823  0.196  91.465  0.482  0.281

# %% [markdown]
# - 多人人脸识别 1

# %%
results4 = r2.json()
results4
# Out:
# {'request_id': '1586678418,10150b7e-5494-4f10-b2a0-78a9d84be282',
#  'time_used': 115,
#  'faces': [{'face_token': '8f481823755fc14d994c22a7fa75c66e',
#    'face_rectangle': {'top': 103, 'left': 83, 'width': 139, 'height': 139},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 20},
#     'smile': {'value': 3.945, 'threshold': 50.0},
#     'emotion': {'anger': 0.001,
#      'disgust': 0.002,
#      'fear': 0.001,
#      'happiness': 0.003,
#      'neutral': 99.993,
#      'sadness': 0.001,
#      'surprise': 0.0}}},
#   {'face_token': '94bd64d2e6943cd29cc76e864987f8fc',
#    'face_rectangle': {'top': 121, 'left': 297, 'width': 136, 'height': 136},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 23},
#     'smile': {'value': 0.191, 'threshold': 50.0},
#     'emotion': {'anger': 0.009,
#      'disgust': 0.075,
#      'fear': 0.009,
#      'happiness': 0.071,
#      'neutral': 99.708,
#      'sadness': 0.059,
#      'surprise': 0.069}}}],
#  'image_id': 'pF2Grcvj0FZOEj/WxhQv4g==',
#  'face_num': 2}

# %%
import pandas as pd
df4 = pd.json_normalize(results4,record_path='faces')
df4 = df4.rename (columns = {"attributes.gender.value":"性别",
                           "attributes.age.value":"年龄",
                           "attributes.smile.value":"笑容",
                           "attributes.smile.threshold":"是否有笑容",
                           "attributes.emotion.anger":"愤怒",
                           "attributes.emotion.disgust":"厌恶",
                           "attributes.emotion.fear":"恐惧",
                           "attributes.emotion.happiness":"高兴",
                           "attributes.emotion.neutral":"平静",
                           "attributes.emotion.sadness":"悲伤",
                           "attributes.emotion.surprise":"惊讶"})
df4 = df4.set_index('face_token')
df4 = df4.iloc[:,4:]
df4.replace({"Male":"男",
            "Female":"女",})
# Out:
#                                  性别  年龄     笑容  是否有笑容     愤怒     厌恶     恐惧  \
# face_token
# 8f481823755fc14d994c22a7fa75c66e  男  20  3.945   50.0  0.001  0.002  0.001
# 94bd64d2e6943cd29cc76e864987f8fc  男  23  0.191   50.0  0.009  0.075  0.009
#
#                                      高兴      平静     悲伤     惊讶
# face_token
# 8f481823755fc14d994c22a7fa75c66e  0.003  99.993  0.001  0.000
# 94bd64d2e6943cd29cc76e864987f8fc  0.071  99.708  0.059  0.069

# %% [markdown]
# - 多人人脸识别 2

# %%
results8 = r3.json()
results8
# Out:
# {'request_id': '1586693824,d3167853-a737-463a-ae29-5cac084d6157',
#  'time_used': 242,
#  'faces': [{'face_token': '99e2d92164ff1175e050d3bf54fd5ca8',
#    'face_rectangle': {'top': 90, 'left': 342, 'width': 86, 'height': 86},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 26},
#     'smile': {'value': 99.485, 'threshold': 50.0},
#     'emotion': {'anger': 0.057,
#      'disgust': 0.057,
#      'fear': 0.111,
#      'happiness': 90.433,
#      'neutral': 0.187,
#      'sadness': 2.979,
#      'surprise': 6.175}}},
#   {'face_token': '9381fcb335bd66180355f5f1d66c3211',
#    'face_rectangle': {'top': 87, 'left': 170, 'width': 80, 'height': 80},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 29},
#     'smile': {'value': 100.0, 'threshold': 50.0},
#     'emotion': {'anger': 0.006,
#      'disgust': 0.001,
#      'fear': 2.46,
#      'happiness': 97.526,
#      'neutral': 0.006,
#      'sadness': 0.001,
#      'surprise': 0.001}}}],
#  'image_id': 'SmokA8HY4AWApXl4pho2Hw==',
#  'face_num': 2}

# %%
import pandas as pd
df8 = pd.json_normalize(results8,record_path='faces')
df8 = df8.rename (columns = {"attributes.gender.value":"性别",
                           "attributes.age.value":"年龄",
                           "attributes.smile.value":"笑容",
                           "attributes.smile.threshold":"是否有笑容",
                           "attributes.emotion.anger":"愤怒",
                           "attributes.emotion.disgust":"厌恶",
                           "attributes.emotion.fear":"恐惧",
                           "attributes.emotion.happiness":"高兴",
                           "attributes.emotion.neutral":"平静",
                           "attributes.emotion.sadness":"悲伤",
                           "attributes.emotion.surprise":"惊讶"})
df8 = df8.set_index('face_token')
df8 = df8.iloc[:,4:]
df8.replace({"Male":"男",
            "Female":"女",})
# Out:
#                                  性别  年龄       笑容  是否有笑容     愤怒     厌恶     恐惧  \
# face_token
# 99e2d92164ff1175e050d3bf54fd5ca8  男  26   99.485   50.0  0.057  0.057  0.111
# 9381fcb335bd66180355f5f1d66c3211  男  29  100.000   50.0  0.006  0.001  2.460
#
#                                       高兴     平静     悲伤     惊讶
# face_token
# 99e2d92164ff1175e050d3bf54fd5ca8  90.433  0.187  2.979  6.175
# 9381fcb335bd66180355f5f1d66c3211  97.526  0.006  0.001  0.001

# %% [markdown]
# ---
# # 3家API不同之处的结论

# %% [markdown]
# * 通过上面三家人脸识别api的数据对比我们可以看到：
#     - Azure：可以分析图像中人物头部方向、人物脸部妆容、发量等特殊数据。
#     - 腾讯云：定位人像五官的位置，给出精确定位数据。
#     - Face++：分析多种情感，可以同时识别不同人脸情感状态。
